# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenmech057/python_projects/blob/main/Number_guess_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
n = random.randrange(1,10)
guess = int(input("Enter any number: "))
while n!= guess:
    if guess < n:
        print("Too low")
        guess = int(input("Enter number again: "))
    elif guess > n:
        print("Too high!")
        guess = int(input("Enter number again: "))
    else:
      break
print("you guessed it right!!")
# Out:
# Enter any number: 5
# Too high!
# Enter number again: 4
# Too high!
# Enter number again: 2
# you guessed it right!!
